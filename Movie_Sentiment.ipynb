# %% [markdown]
# Topic E: Movie Review Sentiment Analysis
#
# Goal: Determine whether user reviews express positive or negative sentiment.
#
# Dataset: IMDB Movie Reviews Dataset.
#
# Tasks: Clean review text, extract n-gram features, fit a classification model, and run error analysis on misclassified reviews.

# %% [markdown]
# #Importing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('/content/IMDB Dataset.csv')

# %%
data.head(10)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# 5  Probably my all-time favorite movie, a story o...  positive
# 6  I sure would like to see a resurrection of a u...  positive
# 7  This show was an amazing, fresh & innovative i...  negative
# 8  Encouraged by the positive comments about this...  negative
# 9  If you like original gut wrenching laughter yo...  positive

# %%
data.info()
#no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
data['review']=data['review'].str.replace('<br /><br />',"",regex=False)

# %%
data['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
data["sentiment"] = data["sentiment"].map({
    "positive": 1,
    "negative": 0
})

# %% [markdown]
# #Cleaning

# %%
import re

def clean_text(x):
    x = x.lower()

    # Preserve ratings
    x = re.sub(r"(\d+)\s*/\s*(\d+)", r"rating_\1_out_of_\2", x)

    # Remove HTML
    x = re.sub(r"<.*?>", " ", x)

    # Keep letters, numbers and underscores
    x = re.sub(r"[^a-z0-9_\s]", " ", x)

    # Remove extra spaces
    x = re.sub(r"\s+", " ", x)

    return x.strip()

data["clean_review"] = data["review"].apply(clean_text)

from sklearn.feature_extraction.text import TfidfVectorizer

#Term Frequency × Inverse Document Frequency
#common everywhere → lower importance
#important/rarer term → higher importance

tfidf = TfidfVectorizer(
    max_features=30000,
    ngram_range=(1, 2),
    min_df=2
)

X = tfidf.fit_transform(data["clean_review"])

# %% [markdown]
# An n-gram is a sequence of n words.

# %% [markdown]
# #Model Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# 1. Split RAW reviews
X_train, X_test, y_train, y_test = train_test_split(
    data["review"],
    data["sentiment"],
    test_size=0.2,
    random_state=42
)

# 2. Create TF-IDF
tfidf = TfidfVectorizer(
    lowercase=True,
    ngram_range=(1, 2),
    max_features=50000,
    min_df=2
)

# 3. Fit ONLY on training data
X_train_vec = tfidf.fit_transform(X_train)

# 4. Transform test data
X_test_vec = tfidf.transform(X_test)

# 5. Train model
model = LogisticRegression(max_iter=1000)

model.fit(X_train_vec, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test_vec)

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score,accuracy_score,f1_score

cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Confusion Matrix:
# [[4448  513]
#  [ 399 4640]]
# Precision: 0.9004463419367359
# Recall: 0.9208176225441556

# %% [markdown]
# #thats a really good metric

# %%
from sklearn.svm import LinearSVC

svc = LinearSVC()
svc.fit(X_train_vec, y_train)
svc_pred = svc.predict(X_test_vec)


print("Accuracy:", accuracy_score(y_test, svc_pred))
print("Precision:", precision_score(y_test, svc_pred))
print("Recall:", recall_score(y_test, svc_pred))
print("F1 Score:", f1_score(y_test, svc_pred))
# Out:
# Accuracy: 0.9093
# Precision: 0.9055751864939144
# Recall: 0.9154594165509029
# F1 Score: 0.9104904766604165

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train_vec, y_train)

rf_pred = rf.predict(X_test_vec)

print("Accuracy:", accuracy_score(y_test, rf_pred))
print("Precision:", precision_score(y_test, rf_pred))
print("Recall:", recall_score(y_test, rf_pred))
print("F1 Score:", f1_score(y_test, rf_pred))
# Out:
# Accuracy: 0.8697
# Precision: 0.8776789324706834
# Recall: 0.8614804524707284
# F1 Score: 0.8695042563845768

# %% [markdown]
# Error Analysis

# %%
import pandas as pd

error_df = pd.DataFrame({
    "review": X_test,
    "actual": y_test,
    "predicted": svc_pred
})

error_df = error_df[
    error_df["actual"] != error_df["predicted"]
]
#contains all the error nodes
print(error_df.head(10))
# Out:
#                                                   review  actual  predicted
# 33553  I really liked this Summerslam due to the look...       1          0
# 6113   The production quality, cast, premise, authent...       1          0
# 15118  This movie was released originally as a soft "...       1          0
# 26497  I went to see Hamlet because I was in between ...       1          0
# 37237  I'm writing this note as a chess player as wel...       0          1
# 33109  Three kids are born during a solar eclipse and...       1          0
# 14644  Eyeliner was worn nearly 6000 years ago in Egy...       1          0
# 24712  A ruthless assassin has been hired to eliminat...       0          1
# 15267  I'm sorry, but this is such a bad movie it's h...       0          1
# 34657  In fact, parts of it I liked a lot. It had som...       0          1

# %%
false_positive = error_df[
    (error_df["actual"] == 0) &
    (error_df["predicted"] == 1)
]
#proportion of all actual negatives that are incorrectly flagged as positive.
print(false_positive.head())
# Out:
#                                                   review  actual  predicted
# 37237  I'm writing this note as a chess player as wel...       0          1
# 24712  A ruthless assassin has been hired to eliminat...       0          1
# 15267  I'm sorry, but this is such a bad movie it's h...       0          1
# 34657  In fact, parts of it I liked a lot. It had som...       0          1
# 46734  OK, imagine that every state in the US, nay, e...       0          1

# %%
false_negative = error_df[
    (error_df["actual"] == 1) &
    (error_df["predicted"] == 0)
]
#proportion of all actual positives that are incorrectly flagged as negative.
print(false_negative.head())
# Out:
#                                                   review  actual  predicted
# 33553  I really liked this Summerslam due to the look...       1          0
# 6113   The production quality, cast, premise, authent...       1          0
# 15118  This movie was released originally as a soft "...       1          0
# 26497  I went to see Hamlet because I was in between ...       1          0
# 33109  Three kids are born during a solar eclipse and...       1          0

# %%
print("False Positives:", len(false_positive))
print("False Negatives:", len(false_negative))
# Out:
# False Positives: 481
# False Negatives: 426

# %%
import joblib
joblib.dump(svc,"model.pkl")
joblib.dump(tfidf, "tfidf.pkl")
# Out:
# ['model.pkl']
